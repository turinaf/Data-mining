# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('disney_movies.csv')
dataset.head(3)
# Out:
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
#
#          Country Language  Running time     Budget    Box office Release date  \
# 0  United States  English          41.0        NaN  4.547200e+01   1937-05-19
# 1  United States  English          83.0  1490000.0  4.180000e+08   1937-12-21
# 2  United States  English          88.0  2600000.0  1.640000e+08   1940-02-07
#
#    imdb  ...  rotten_tomatoes  \
# 0   7.2  ...              NaN
# 1   7.6  ...              NaN
# 2   7.4  ...              73%
#
#                                          Directed by  Produced by  \
# 0                                                NaN          NaN
# 1  ['David Hand (supervising)', 'William Cottrell...  Walt Disney
# ...

# %%
dataset.drop('Unnamed: 0', axis=1, inplace=True)
dataset.head()
# Out:
#                              title       Production company        Country  \
# 0          Academy Award Review of  Walt Disney Productions  United States
# 1  Snow White and the Seven Dwarfs  Walt Disney Productions  United States
# 2                        Pinocchio  Walt Disney Productions  United States
# 3                         Fantasia  Walt Disney Productions  United States
# 4             The Reluctant Dragon  Walt Disney Productions  United States
#
#   Language  Running time     Budget    Box office Release date  imdb  \
# 0  English          41.0        NaN  4.547200e+01   1937-05-19   7.2
# 1  English          83.0  1490000.0  4.180000e+08   1937-12-21   7.6
# 2  English          88.0  2600000.0  1.640000e+08   1940-02-07   7.4
# 3  English         126.0  2280000.0  8.330000e+07   1940-11-13   7.7
# 4  English          74.0   600000.0  9.600000e+05   1941-06-20   6.9
#
#    metascore rotten_tomatoes  \
# 0        NaN             NaN
# 1       95.0             NaN
# ...

# %%
dataset.describe(include=['int', 'float'])
# Out:
#        Running time        Budget    Box office        imdb   metascore
# count    430.000000  2.780000e+02  3.580000e+02  424.000000  293.000000
# mean      98.076744  5.638595e+07  1.702417e+08    6.566274   61.860068
# std       21.418924  7.111427e+07  2.803541e+08    0.965122   16.756236
# min       40.000000  4.400000e+00  7.700000e+00    1.500000   18.000000
# 25%       86.250000  6.000000e+06  1.042500e+07    6.100000   49.000000
# 50%       96.000000  2.500000e+07  4.470000e+07    6.600000   61.000000
# 75%      107.000000  8.500000e+07  1.867750e+08    7.200000   74.000000
# max      306.000000  4.106000e+08  1.657000e+09    8.600000   99.000000

# %%
df = pd.read_csv('labelled_movie_dataset.csv')
df.head()
# Out:
#              title  Running_time     Budget   Box_office Release_date  imdb  \
# 0        Pinocchio          88.0  2600000.0  164000000.0   1940-02-07   7.4
# 1         Fantasia         126.0  2280000.0   83300000.0   1940-11-13   7.7
# 2            Dumbo          64.0   950000.0    1300000.0   1941-10-23   7.2
# 3            Bambi          70.0   858000.0  267400000.0   1942-08-09   7.3
# 4  Make Mine Music          75.0  1350000.0    3275000.0   1946-04-20   6.3
#
#    metascore  rotten_tomatoes         Main_actor  Second_actor  \
# 0        9.9              7.3      Cliff Edwards  Dickie Jones
# 1        9.6              9.5  Leopold Stokowski  Deems Taylor
# 2        9.6              9.8      Edward Brophy   Herman Bing
# 3        9.1              9.0          see below       missing
# 4        6.0              7.0        Nelson Eddy       missing
#
#                Director  Main_actor_rate  Director_rate  Second_actor_rate  \
# ...

# %%
df['Category'].value_counts()
# Out:
# Blockbuster    99
# Flop           65
# Hit            59
# Name: Category, dtype: int64

# %%
df.hist(column='Box_office', ylabelsize=10, xlabelsize=10, bins=10)
# plt.hist(df['Box_office'])
# plt.savefig('Box_office_hist')
# Out:
# array([[<AxesSubplot:title={'center':'Box_office'}>]], dtype=object)

# %%
df.hist(column='Budget', ylabelsize=10, xlabelsize=10, bins=10)
# plt.hist(df['Budget'])
# plt.savefig('Budget_hist')
# Out:
# array([[<AxesSubplot:title={'center':'Budget'}>]], dtype=object)

# %%
df.plot(kind='scatter',x='imdb',y='Box_office',color='green')
plt.savefig('imdb_box-office_plot')

# %%
df.plot(kind='scatter',x='metascore',y='Box_office',color='green')
plt.savefig('metascore_box-office_plot')

# %%
df.plot(kind='scatter',x='rotten_tomatoes',y='Box_office',color='green')
plt.savefig('rottentomatoes_box-office_plot')

# %%
df.plot(kind='scatter',x='Director_rate',y='Box_office',color='green')
plt.savefig('director_box-office_plot')

# %%
df.plot(kind='scatter',x='Main_actor_rate',y='Box_office',color='green')
plt.savefig('Mainactor_box-office_plot')

# %%
# The metrics scores we are using are from the model evaluation
def add_value_label(x_list,y_list):
    for i in range(1, len(x_list)+1):
        plt.text(i-1.2,y_list[i-1]+1,y_list[i-1])
        
graph_data = {'metrics': ['Accuracy', 'Precision', 'Recall', 'F1-score'],
             'scores': [97.78, 96.97, 97.62, 97.18]} 

df = pd.DataFrame(graph_data, columns=['metrics', 'scores'])

colors = ['teal', 'purple', 'brown', 'green']
fig = plt.figure()
plt.bar(df['metrics'], df['scores'], color=colors, width=0.5, align='center')
add_value_label(df['metrics'], df['scores'])
plt.title('Model Evaluation')
plt.xlabel('Evaluation Metrics')
plt.ylabel('Score %')
# plt.text(84, 95, '93.33%')
plt.show()
fig.savefig("model_evaluation2")

# %%
# 
def add_value_label(x_list,y_list):
    for i in range(1, len(x_list)+1):
        plt.text(i-1.2,y_list[i-1]+1,y_list[i-1])
        
graph_data = {'cat': ['Blockbuster', 'Hit', 'Flop'],
             'values': [99, 65, 59]} 

df = pd.DataFrame(graph_data, columns=['cat', 'values'])

colors = ['green', 'teal', 'brown']
fig = plt.figure()
plt.bar(df['cat'], df['values'], color=colors, width=0.5, align='center')
add_value_label(df['cat'], df['values'])
plt.title('Category count')
plt.xlabel('Categories')
plt.ylabel('Count')

plt.show()
fig.savefig("cat_count")

# %%
import seaborn as sns
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="Category", height=4.4) \
   .map(plt.scatter, "imdb", "metascore") \
   .add_legend();
plt.show();
plt.savefig("imdb_metascore")

# %%
import seaborn as sns
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="Category", height=4.4) \
   .map(plt.scatter, "rotten_tomatoes", "metascore") \
   .add_legend();
plt.show();

# %%
import seaborn as sns
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="Category", height=4.4) \
   .map(plt.scatter, "Main_actor_rate", "imdb") \
   .add_legend();
plt.show();

# %%
import seaborn as sns
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="Category", height=4.4) \
   .map(plt.scatter, "Director_rate", "metascore") \
   .add_legend();
plt.show();
